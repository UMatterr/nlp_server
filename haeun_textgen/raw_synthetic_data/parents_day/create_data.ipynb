# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/h/anaconda3/lib/python3.11/site-packages (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (2.5.3)
# Requirement already satisfied: sniffio in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/h/anaconda3/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /Users/h/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /Users/h/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/h/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/h/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/h/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.14.6)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

from openai import OpenAI
client = OpenAI(api_key="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")

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'항상 저희를 위해 고생하시는 부모님께 감사드립니다. 앞으로 더욱더 효도하겠습니다. 늘 건강하세요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "효도"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        }
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 부모님께서 항상 효도로 가르침 주셔서 감사합니다.
# 2. 언제나 저희를 위해 헌신해주시는 부모님에게 감사드립니다.
# 3. 부모님의 효도 정신에 감동받아 더욱 노력하겠습니다.
# 4. 늘 효도의 중요성을 깨닫게 해주시는 부모님께 감사드립니다.
# 5. 부모님의 사랑과 효도 정신이 저에게 큰 힘이 됩니다.
# 6. 효도는 가장 소중하고 아름다운 은혜입니다.
# 7. 부모님의 효도 정신이 저에게는 큰 보탬이 됩니다.
# 8. 부모님께 감사의 마음을 전해드리고 싶습니다.
# 9. 부모님께서 가르쳐주시는 효도의 중요성을 몸소 느낍니다.
# 10. 부모님을 위해 더 많이 효도하는 사람이 되고 싶습니다.
# 11. 부모님의 가르침에 따라 효도의 길을 걸어가겠습니다.
# 12. 부모님의 효도 정신이 저에게는 큰 자랑입니다.
# 13. 부모님의 효도 정신이 나를 성장시켜줍니다.
# 14. 늘 부모님을 위해 더 많이 노력하고 효도하겠습니다.
# 15. 부모님의 효도 정신이 나를 더욱 겸손하게 만듭니다.
# 16. 부모님의 효도 정신은 영원히 가슴속에 간직하겠습니다.
# 17. 부모님께서 제자리에서 효도하는 모습이 참으로 멋지십니다.
# 18. 부모님의 효도 정신을 잊지 않고 끝까지 지키겠습니다.
# 19. 부모님께 감사의 뜻을 전하며 더욱 효도하겠습니다.
# 20. 부모님께서 가르쳐주신 효도 정신을 실천하도록 노력하겠습니다.
# 21. 부모님의 효도 정신이 나를 더욱 완전한 사람으로 만듭니다.
# 22. 부모님의 효도 정신은 저에게 큰 도전과 성장의 기회가 됩니다.
# 23. 부모님께서 저에게 가르쳐준 효도의 미덕을 따라가겠습니다.
# 24. 부모님의 효도 정신은 저를 더욱 강하고 올바른 길로 이끕니다.
# 25. 부모님의 효도 정신이 나를 더욱 성숙하게 만듭니다.
# 26. 부모님을 위해 더욱 노력하고 효도하는 모습을 보여드리겠습니다.
# 27. 부모님의 효도 정신이 나를 더욱 용기를 갖게 만듭니다.
# 28. 부모님을 위해 더욱 효도하는 모습을 보여드리고 싶습니다.
# 29. 부모님의 효도 정신은 나에게 큰 울타리가 됩니다.
# 30. 부모님의 효도 정신으로 더 나은 사람이 될 수 있기를 바랍니다.
# 31. 부모님의 사랑과 효도 정신에 감사드립니다.
# 32. 부모님을 위해 더욱 노력하고 효도하겠습니다.
# 33. 부모님의 효도 정신에서 더 많은 교훈을 받고 있습니다.
# 34. 부모님의 효도 정신이 나를 더욱 존경스럽게 만듭니다.
# 35. 부모님을 위해 더욱 애를 써서 효도하는 모습을 보여드리겠습니다.
# 36. 부모님의 사랑과 효도 정신이 나를 더욱 강하게 만듭니다.
# 37. 부모님의 효도 정신에 영원토록 감사드립니다.
# 38. 부모님을 위해 더욱 노력하고 효도하겠습니다.
# 39. 부모님의 가르침에 따라 효도하는 모습을 보여드리겠습니다.
# 40. 부모님의 효도 정신은 나에게 큰 자랑입니다.
# 41. 부모님의 효도 정신으로 나를 성장시켜주시는 것을 감사합니다.
# 42. 부모님의 효도 정신이 나를 더욱 성숙하게 만듭니다.
# 43. 부모님을 위해 더욱 효도하는 모습을 지속적으로 보여드리겠습니다.
# 44. 부모님의 효도 정신이 나를 더욱 감사한 사람으로 만듭니다.
# 45. 부모님의 효도 정신이 나에게 큰 영감이 됩니다.
# 46. 부모님을 위해 더욱 노력하고 효도하는 사람이 되고 싶습니다.
# 47. 부모님의 효도 정신은 나에게 큰 자랑이 됩니다.
# 48. 부모님의 효도 정신으로 더욱 좋은 사람이 되도록 노력하겠습니다.
# 49. 부모님의 가르침에 따라 효도의 길을 지켜가겠습니다.
# 50. 부모님의 효도 정신은 저에게 큰 영감과 힘이 됩니다.

# %%
data_string=response_text
data = data_string.split('\n')

structured_data = []
for item in data:
    parts = item.split(". ", 1)  # Split only on the first occurrence
    if len(parts) == 2:
        id_, sentence = parts
        structured_data.append({'id': id_, 'sentence': sentence, 'label': 10})

# Convert the structured data into a pandas DataFrame
df = pd.DataFrame(structured_data)

df.to_csv('0to50.csv', index=False, encoding='utf-8-sig')

# %%
df
# Out:
#     id                             sentence  label
# 0    1          부모님께서 항상 효도로 가르침 주셔서 감사합니다.     10
# 1    2      언제나 저희를 위해 헌신해주시는 부모님에게 감사드립니다.     10
# 2    3         부모님의 효도 정신에 감동받아 더욱 노력하겠습니다.     10
# 3    4     늘 효도의 중요성을 깨닫게 해주시는 부모님께 감사드립니다.     10
# 4    5        부모님의 사랑과 효도 정신이 저에게 큰 힘이 됩니다.     10
# 5    6              효도는 가장 소중하고 아름다운 은혜입니다.     10
# 6    7          부모님의 효도 정신이 저에게는 큰 보탬이 됩니다.     10
# 7    8             부모님께 감사의 마음을 전해드리고 싶습니다.     10
# 8    9       부모님께서 가르쳐주시는 효도의 중요성을 몸소 느낍니다.     10
# 9   10       부모님을 위해 더 많이 효도하는 사람이 되고 싶습니다.     10
# 10  11         부모님의 가르침에 따라 효도의 길을 걸어가겠습니다.     10
# 11  12            부모님의 효도 정신이 저에게는 큰 자랑입니다.     10
# 12  13              부모님의 효도 정신이 나를 성장시켜줍니다.     10
# 13  14         늘 부모님을 위해 더 많이 노력하고 효도하겠습니다.     10
# 14  15         부모님의 효도 정신이 나를 더욱 겸손하게 만듭니다.     10
# 15  16        부모님의 효도 정신은 영원히 가슴속에 간직하겠습니다.     10
# 16  17      부모님께서 제자리에서 효도하는 모습이 참으로 멋지십니다.     10
# 17  18        부모님의 효도 정신을 잊지 않고 끝까지 지키겠습니다.     10
# 18  19          부모님께 감사의 뜻을 전하며 더욱 효도하겠습니다.     10
# 19  20    부모님께서 가르쳐주신 효도 정신을 실천하도록 노력하겠습니다.     10
# 20  21     부모님의 효도 정신이 나를 더욱 완전한 사람으로 만듭니다.     10
# 21  22   부모님의 효도 정신은 저에게 큰 도전과 성장의 기회가 됩니다.     10
# 22  23      부모님께서 저에게 가르쳐준 효도의 미덕을 따라가겠습니다.     10
# 23  24   부모님의 효도 정신은 저를 더욱 강하고 올바른 길로 이끕니다.     10
# 24  25         부모님의 효도 정신이 나를 더욱 성숙하게 만듭니다.     10
# 25  26   부모님을 위해 더욱 노력하고 효도하는 모습을 보여드리겠습니다.     10
# 26  27       부모님의 효도 정신이 나를 더욱 용기를 갖게 만듭니다.     10
# 27  28      부모님을 위해 더욱 효도하는 모습을 보여드리고 싶습니다.     10
# 28  29          부모님의 효도 정신은 나에게 큰 울타리가 됩니다.     10
# 29  30  부모님의 효도 정신으로 더 나은 사람이 될 수 있기를 바랍니다.     10
# 30  31              부모님의 사랑과 효도 정신에 감사드립니다.     10
# 31  32             부모님을 위해 더욱 노력하고 효도하겠습니다.     10
# 32  33       부모님의 효도 정신에서 더 많은 교훈을 받고 있습니다.     10
# 33  34        부모님의 효도 정신이 나를 더욱 존경스럽게 만듭니다.     10
# 34  35  부모님을 위해 더욱 애를 써서 효도하는 모습을 보여드리겠습니다.     10
# 35  36      부모님의 사랑과 효도 정신이 나를 더욱 강하게 만듭니다.     10
# 36  37             부모님의 효도 정신에 영원토록 감사드립니다.     10
# 37  38             부모님을 위해 더욱 노력하고 효도하겠습니다.     10
# 38  39      부모님의 가르침에 따라 효도하는 모습을 보여드리겠습니다.     10
# 39  40             부모님의 효도 정신은 나에게 큰 자랑입니다.     10
# 40  41    부모님의 효도 정신으로 나를 성장시켜주시는 것을 감사합니다.     10
# 41  42         부모님의 효도 정신이 나를 더욱 성숙하게 만듭니다.     10
# 42  43  부모님을 위해 더욱 효도하는 모습을 지속적으로 보여드리겠습니다.     10
# 43  44     부모님의 효도 정신이 나를 더욱 감사한 사람으로 만듭니다.     10
# 44  45           부모님의 효도 정신이 나에게 큰 영감이 됩니다.     10
# 45  46    부모님을 위해 더욱 노력하고 효도하는 사람이 되고 싶습니다.     10
# 46  47           부모님의 효도 정신은 나에게 큰 자랑이 됩니다.     10
# 47  48  부모님의 효도 정신으로 더욱 좋은 사람이 되도록 노력하겠습니다.     10
# 48  49         부모님의 가르침에 따라 효도의 길을 지켜가겠습니다.     10
# 49  50        부모님의 효도 정신은 저에게 큰 영감과 힘이 됩니다.     10

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'지난 세월 돌이켜보면 미안함뿐이네요. 부디 건강 챙기시고 오랫동안 옆에 계셔주세요. 고맙고 또 고맙습니다.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "감사"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        },
        # {
        # "role": "assistant",
        #   "content": "정말 50개를 생성해드릴까요?"
        # },
        # {
        #   "role": "user",
        #   "content": "50개 생성해줘"
        # }
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 과거의 모든 고생과 희생에 감사를 표합니다.
# 2. 매 순간을 함께 보내는 것이 위로가 되는 그런 날이길 바랍니다.
# 3. 나에게 힘이 되어주신 모든 것에 감사 드립니다.
# 4. 오래도록 영원한 사랑을 함께 느끼고 싶습니다.
# 5. 함께한 날들이 행복한 기억으로 남아 있습니다.
# 6. 감사함을 담아 향유할 수 있는 그런 맑고 축복받은 날이랍니다.
# 7. 늘 마음 속으로 당신만을 담아 두고 싶습니다.
# 8. 함께한 모든 세월이 오래도록 이어지길 기원합니다.
# 9. 땀과 눈물이 어린 나날들, 그 모든 것에 감사를 전합니다.
# 10. 함께한 시간을 소중히 여기며 감사함을 전합니다.
# 11. 지금 이 시간을 행복한 시간으로 만들어 준 것에 감사합니다.
# 12. 덕분에 선물같은 행복한 날이네요.
# 13. 함께여서 더 힘이 나고 행복한 것 같습니다.
# 14. 함께한 모든 순간이 귀하고, 소중하고, 감사한 시간이었습니다.
# 15. 항상 슬픔과 기쁨을 함께 나누고 싶습니다.
# 16. 그댈 만난 순간부터 나의 세상이 아름다워졌습니다.
# 17. 너무 고마워요, 그저 고맙다고 말할 수밖에 없습니다.
# 18. 곁에서 응원해주신 모든 것에 감사를 표합니다.
# 19. 모든 게 너무나 소중하고 감동적이길 바랍니다.
# 20. 영원토록 소중한 사람으로 남아주세요.
# 21. 함께한 모든 날이 행복한 일들로 가득했습니다.
# 22. 내 곁에 있어주셔서 감사합니다, 그리고 또 고맙습니다.
# 23. 영원한 변함없는 사랑으로 함께해주실 수 있길 바랍니다.
# 24. 언제나 당신의 곁에서 행복한 나날이 계속되길 기원합니다.
# 25. 서로의 손을 잡아 힘을 실어주며 함께 걸어가고 싶습니다.
# 26. 오래도록 행복한 일들이 많이 눈에 들어오길 바랍니다.
# 27. 당신의 따뜻한 사랑이 나의 힘이 되었습니다.
# 28. 곁에 있는 것만으로도 힘이 되는 그런 영원한 사랑이길 바랍니다.
# 29. 감사한 마음을 담아 이렇게 글을 써봅니다.
# 30. 오늘도 마음속에 당신과 함께하며 감사를 전합니다.
# 31. 오랜 세월을 곁에서 함께할 수 있기를 기원합니다.
# 32. 함께한 시간이 무한하게 이어진다면 얼마나 좋을까요.
# 33. 당신이 있어서 내 삶이 더욱 풍요로워져서 감사합니다.
# 34. 함께한 순간들이 나에게 큰 힘이 되었습니다.
# 35. 항상 당신만을 의지하고 싶습니다.
# 36. 함께한 모든 시간이 곧 나의 선물입니다.
# 37. 이런 유난히 특별한 날에 당신이 곁에 계셔주셔서 감사합니다.
# 38. 그댈 만나서 행복한 것은 정말 행운이었습니다.
# 39. 당신이 있어서 내일이 또 한 번 기대되네요.
# 40. 어버이님과 있을 때 가장 큰 행복을 느꼈습니다.
# 41. 당신이 내 곁에 있어서 너무나 행복합니다.
# 42. 영원토록 오늘 같은 행복을 누릴 수 있다면 얼마나 좋을까요.
# 43. 당신의 따뜻함이 나의 가장 큰 힘이었습니다.
# 44. 오늘도 함께하며 감사함을 전하고 싶습니다.
# 45. 함께한 날들이 항상 빛나게 해주셔서 감사합니다.
# 46. 오늘도 당신과 함께라서 정말 감사합니다.
# 47. 당신을 만난 순간부터 나의 세상이 너무나 아름다워졌습니다.
# 48. 항상 당신이 함께해주면 웃을 수 있는 그런 날이렇습니다.
# 49. 내 곁에서 떠나지 말아주세요, 항상 감사합니다.
# 50. 함께한 모든 순간이 소중하고 보람찬 날들이었습니다.
#
# 언제나 당신을 향한 감사와 사랑을 전합니다.

# %%
def save_data_to_csv(file_name, data):
    data_string=response_text
    data = data_string.split('\n')

    structured_data = []
    for item in data:
        parts = item.split(". ", 1)  # Split only on the first occurrence
        if len(parts) == 2:
            id_, sentence = parts
            structured_data.append({'id': id_, 'sentence': sentence, 'label': 10})

    # Convert the structured data into a pandas DataFrame
    df = pd.DataFrame(structured_data)

    df.to_csv(f'{file_name}.csv', index=False, encoding='utf-8-sig')
    
save_data_to_csv("50to100", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'낳아주시고, 키워주셔서 고맙습니다. 사랑해요!' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "사랑"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        },
        # {
        # "role": "assistant",
        #   "content": "50개를 반환하지 못하면 어떡할까요?"
        # },
        # {
        #   "role": "user",
        #   "content": "50개 생성해서 반환할수 있을때까지 생성해줘"
        # }
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 사랑으로 가득한 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 2. 사랑으로 다정한 마음을 담아 올테니, 언제나 행복하시길 바랍니다.
# 3. 사랑의 정성으로 감사를 표현하며, 언제나 건강하시고 행복하세요.
# 4. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.
# 5. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 6. 사랑의 정성을 담아, 언제나 고맙고 사랑합니다.
# 7. 사랑과 감사의 마음을 전하며, 언제나 행복과 건강을 빕니다.
# 8. 사랑으로 충만한 마음을 전합니다. 언제나 행복하세요.
# 9. 사랑에 감사를 표현하며, 언제나 행복과 건강을 빕니다.
# 10. 사랑으로 가득찬 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 11. 사랑과 감사의 마음을 담아, 언제나 행복하시길 바랍니다.
# 12. 사랑의 정성으로 고맙다는 말씀을 전합니다. 언제나 건강하세요.
# 13. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 14. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.
# 15. 사랑과 감사의 마음을 전하며, 언제나 행복과 건강을 빕니다.
# 16. 사랑의 정성을 담아, 언제나 고맙고 사랑합니다.
# 17. 사랑으로 충만한 마음을 전합니다. 언제나 행복하세요.
# 18. 사랑에 감사를 표현하며, 언제나 행복과 건강을 빕니다.
# 19. 사랑으로 가득찬 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 20. 사랑과 감사의 마음을 담아, 언제나 행복하시길 바랍니다.
# 21. 사랑의 정성으로 고맙다는 말씀을 전합니다. 언제나 건강하세요.
# 22. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 23. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.
# 24. 사랑과 감사의 마음을 전하며, 언제나 행복과 건강을 빕니다.
# 25. 사랑의 정성을 담아, 언제나 고맙고 사랑합니다.
# 26. 사랑으로 충만한 마음을 전합니다. 언제나 행복하세요.
# 27. 사랑에 감사를 표현하며, 언제나 행복과 건강을 빕니다.
# 28. 사랑으로 가득찬 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 29. 사랑과 감사의 마음을 담아, 언제나 행복하시길 바랍니다.
# 30. 사랑의 정성으로 고맙다는 말씀을 전합니다. 언제나 건강하세요.
# 31. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 32. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.
# 33. 사랑과 감사의 마음을 전하며, 언제나 행복과 건강을 빕니다.
# 34. 사랑의 정성을 담아, 언제나 고맙고 사랑합니다.
# 35. 사랑으로 충만한 마음을 전합니다. 언제나 행복하세요.
# 36. 사랑에 감사를 표현하며, 언제나 행복과 건강을 빕니다.
# 37. 사랑으로 가득찬 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 38. 사랑과 감사의 마음을 담아, 언제나 행복하시길 바랍니다.
# 39. 사랑의 정성으로 고맙다는 말씀을 전합니다. 언제나 건강하세요.
# 40. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 41. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.
# 42. 사랑과 감사의 마음을 전하며, 언제나 행복과 건강을 빕니다.
# 43. 사랑의 정성을 담아, 언제나 고맙고 사랑합니다.
# 44. 사랑으로 충만한 마음을 전합니다. 언제나 행복하세요.
# 45. 사랑에 감사를 표현하며, 언제나 행복과 건강을 빕니다.
# 46. 사랑으로 가득찬 마음을 전합니다. 언제나 고맙고 사랑합니다.
# 47. 사랑과 감사의 마음을 담아, 언제나 행복하시길 바랍니다.
# 48. 사랑의 정성으로 고맙다는 말씀을 전합니다. 언제나 건강하세요.
# 49. 사랑으로 감동을 전하며, 언제나 행복과 건강을 빕니다.
# 50. 사랑에 감사하는 마음으로, 언제나 행복하시길 기원합니다.

# %%
save_data_to_csv("100to150", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'어버이의 은혜 감사하고 사랑합니다. 오래오래 함께 해주세요' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "함께"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        },
        # {
        # "role": "assistant",
        #   "content": "정말 50개를 생성할까요?"
        # },
        # {
        #   "role": "user",
        #   "content": "응, 정말 50개 생성해줘"
        # }
        {
          "role": "user",
          "content": "문장만 반환해줘"
        }
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 함께 지내는 모든 순간이 소중합니다. 언제나 고맙고 사랑합니다.
# 2. 함께 할 수 있어서 행복합니다. 언제나 힘이 되주셔서 감사합니다.
# 3. 함께 한 날들이 소중한 추억으로 남습니다. 항상 고맙고 사랑합니다.
# 4. 함께 할 수 있는 것이 큰 행운입니다. 고맙고 사랑합니다.
# 5. 함께 함으로써 더 강해지는 우리 가족입니다. 항상 늘 감사하고 사랑합니다.
# 6. 함께 해주셔서 고맙고 사랑합니다. 영원토록 함께하세요.
# 7. 함께 할 수 있어서 행복합니다. 언제나 감사하고 사랑합니다.
# 8. 함께 함으로써 많은 것을 배우고 느꼈습니다. 언제나 고맙고 사랑합니다.
# 9. 함께 한 모든 순간이 소중하고 행복했습니다. 영원한 감사와 사랑을 전합니다.
# 10. 함께 할 수 있다는 것에 감사합니다. 영원한 사랑을 보냅니다.

# %%
save_data_to_csv("150to200", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'세상에서 가장 사랑하는 우리 엄마아빠 고맙습니다.  낳아주시고, 키워주셔서 고맙습니다. 사랑해요!' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "잘지내시죠"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개, 문장만"
        },
        # {
        # "role": "assistant",
        #   "content": "정말 50개를 생성할까요?"
        # },
        # {
        #   "role": "user",
        #   "content": "응, 정말 50개 생성해줘"
        # }
        # {
        #   "role": "user",
        #   "content": "문장만 반환해줘"
        # }
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 세상에서 가장 소중한 어머니, 아버지께 감사드립니다.
# 2. 엄마 아빠! 항상 고맙습니다.
# 3. 사랑하는 부모님, 언제나 감사합니다.
# 4. 엄마 아빠! 마음속에 항상 담고 있어요.
# 5. 가장 아끼는 엄마 아빠, 사랑합니다.
# 6. 부모님, 항상 편히 쉬어주세요.
# 7. 사랑하는 엄마 아빠, 건강하세요.
# 8. 부모님께 감사드립니다. 항상 힘내시길 바랍니다.
# 9. 어버이 날, 부모님과 함께 기쁜 시간 보내길 바래요.
# 10. 엄마 아빠, 건강이 최고입니다. 항상 챙겨주세요.
# 11. 부모님께 감사드리며, 사랑합니다.
# 12. 부모님, 사랑합니다. 언제나 행복하시길 바랍니다.
# 13. 부모님, 감사드립니다. 사랑합니다.
# 14. 부모님, 항상 행복하시길 바래요. 사랑합니다.
# 15. 엄마 아빠, 사랑합니다. 힘내세요.
# 16. 부모님, 고맙습니다. 항상 미소 지으세요.
# 17. 부모님, 언제나 고맙습니다. 사랑합니다.
# 18. 엄마 아빠, 마음이 따뜻해져요. 감사합니다.
# 19. 부모님께 감사드립니다. 사랑합니다.
# 20. 엄마 아빠, 언제나 제 곁에 있어주세요. 사랑합니다.
# 21. 부모님, 사랑합니다. 항상 행복하길 바랍니다.
# 22. 엄마 아빠께 감사드립니다. 언제나 사랑합니다.
# 23. 사랑하는 엄마 아빠께 감사드립니다. 항상 고맙습니다.
# 24. 엄마 아빠, 정말 사랑합니다. 감사합니다.
# 25. 부모님께 감사드립니다. 사랑합니다.

# %%
save_data_to_csv("etc_1", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'쑥스러운 마음에 자주 표현하지는 못하지만 감사하고, 사랑합니다. 세상에서 가장 사랑하는 우리 엄마아빠 고맙습니다.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "엄마아빠"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 어버이 날을 맞아 엄마아빠께 깊은 감사와 사랑을 전합니다.
# 2. 엄마아빠께 언제나 힘과 사랑을 받고 있어서 감사합니다.
# 3. 세상에서 가장 소중한 엄마와 아빠에게 행복한 어버이 날이 되기를 기대합니다.
# 4. 우리 엄마아빠께 이 마음이 닿을 수 있기를 진심으로 바랍니다.
# 5. 항상 편안함과 사랑으로 가득한 가정을 만들어주신 엄마아빠에게 감사합니다.
# 6. 언제나 내 곁에서 가장 든든한 존재인 엄마아빠, 사랑합니다.
# 7. 엄마아빠의 노고에 대한 감사와 사랑을 마음 한 켠에 담아두고 있습니다.
# 8. 엄마아빠께 받은 사랑과 격려에 대해 언제나 감사하고 있습니다.
# 9. 어버이 날을 맞아, 나의 모든 사랑을 엄마아빠에게 전합니다.
# 10. 엄마아빠께 오늘 하루가 특별하고 행복한 날이 되기를 기도합니다.
# 11. 언제나 엄마아빠에게 받은 사랑을 기억하며 고맙다고 전합니다.
# 12. 엄마아빠께 내 마음이 전해지길 바라며 우리 가족에게 행복을 빕니다.
# 13. 엄마아빠의 빛나는 사랑에 감사하고, 세상에서 가장 사랑합니다.
# 14. 나를 위해 늘 헌신하고 사랑해주시는 엄마아빠께 감사를 전합니다.
# 15. 어버이 날을 맞아 엄마아빠께 특별한 사랑을 전하고 싶어요.
# 16. 엄마아빠께 항상 좋은 일만 있기를, 건강하시고 사랑합니다.
# 17. 엄마아빠께 나는 항상 감사하며 사랑하고 있습니다.
# 18. 엄마아빠에게 받은 사랑을 다시 한번 고마운 마음으로 전합니다.
# 19. 세상에서 단 하나뿐인 엄마아빠, 사랑합니다. 언제나 행복하시길 바랍니다.
# 20. 엄마아빠가 없었다면 나는 없었을 것이라는 것을 항상 감사함을 가지며 사랑합니다.
# 21. 어버이 날을 맞아, 엄마아빠께 제 마음을 가득 담아 전합니다.
# 22. 항상 나의 편에 서서 가장 든든한 존재인 엄마아빠에게 사랑을 보냅니다.
# 23. 엄마아빠께 받은 사랑에 대해 말로 다 표현할 수 없지만, 언제나 감사합니다.
# 24. 나에게 가장 소중한 엄마아빠께 어버이 날을 맞아 사랑을 전합니다.
# 25. 엄마아빠의 무한한 투사와 따뜻한 사랑에 항상 감사하고 있습니다.
# 26. 엄마아빠와 함께 행복한 순간들을 나누고 싶어요. 감사합니다, 사랑합니다.
# 27. 엄마아빠께 언제나 받은 사랑에 진심으로 감사하고, 사랑합니다.
# 28. 어버이 날을 맞아 엄마아빠에게 감사와 사랑을 전합니다.
# 29. 엄마아빠께 영원한 사랑과 존경을 바랍니다. 행복하세요.
# 30. 엄마와 아빠에게 보내는 마음이 가득한 어버이 날이 되길 바래요.
# 31. 엄마아빠께 받은 사랑에 대해 늘 감사하며, 사랑합니다.
# 32. 엄마아빠께 오늘 하루가 특별하고 따뜻한 날이 되길 기원합니다.
# 33. 엄마아빠에 대한 마음을 다 할 수 없지만, 항상 사랑하고 감사하고 있습니다.
# 34. 세상에서 제일 특별한 엄마아빠에게 어버이 날 축하와 사랑을 전합니다.
# 35. 엄마아빠께 받은 무한한 사랑과 격려에 감사합니다. 사랑합니다.
# 36. 나의 삶에 기적 같은 존재인 엄마아빠께 감사하고 사랑합니다.
# 37. 엄마아빠가 지닌 무한한 사랑에 항상 감사하며, 사랑합니다.
# 38. 어버이 날을 맞아, 엄마아빠께 제 마음을 전하며 행복을 빕니다.
# 39. 엄마아빠께 항상 받은 따스한 사랑에 감사하며, 사랑합니다.
# 40. 엄마아빠가 있어서 나는 행복합니다. 항상 감사하고 사랑합니다.
# 41. 언제나 나의 곁에서 힘이 되어주신 엄마아빠에게 감사합니다.
# 42. 엄마와 아빠께, 항상 아끼고 사랑하는 나의 마음을 전합니다.
# 43. 엄마아빠에 대한 무한한 사랑을 가슴 깊이 담아 세상에서 가장 사랑합니다.
# 44. 오늘은 어버이 날, 나의 엄마아빠께 사랑과 감사를 전합니다.
# 45. 엄마아빠께 받은 사랑에 대한 감사를 담아 세상에서 가장 사랑합니다.
# 46. 엄마아빠에게 받은 사랑과 배움에 대해 항상 감사하며 사랑합니다.
# 47. 어버이 날, 나의 가장 소중한 엄마와 아빠에게 감사와 사랑을 전합니다.
# 48. 엄마아빠께 든든한 힘이 되어주신 모든 것에 대해 감사하며 사랑합니다.
# 49. 엄마아빠께 온 마음을 담아 어버이 날을 축하하며 사랑을 전합니다.
# 50. 언제나 나의 곁에서 행복을 주는 엄마아빠께 감사하고 사랑합니다.

# %%
save_data_to_csv("200to250", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'늘 받기만 한 사랑. 저도 더 잘할께요' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "사랑"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 사랑 받는 게 너무 어려우셨죠? 이제는 제가 사랑을 돌려드릴게요.
# 2. 언제나 사랑만 받다니 죄송해요. 이제는 제가 더 노력할게요.
# 3. 받기만 하지말고 나누어주는 사랑이 되어야겠죠.
# 4. 사랑 받는 것 말고 주는 것도 중요하다는 걸 알게 해줘서 고맙습니다.
# 5. 이제는 제가 사랑 넘쳐나는 사람이 되도록 노력하겠습니다.
# 6. 받는 사랑에 만족하기보다 주는 사랑에 충실해야겠죠.
# 7. 어버이 날을 맞아 더 나누어주는 사랑이 되도록 노력하겠습니다.
# 8. 받는 사랑이 아니라 주는 사랑이 되기 위해 당신을 배웅하겠어요.
# 9. 어버이 날을 맞아, 사랑 받는 것이 아니라 사랑 주는 사람이 되겠습니다.
# 10. 받을 뿐인 사랑이 아니라 나누어주는 사랑이 되도록 노력하겠습니다.
# 11. 사랑 받는 것에 만족하지 않고 더 챙겨주는 사랑이 되도록 하겠습니다.
# 12. 무조건 받는 사랑이 아니라 참으로 주는 사랑에 힘써보겠습니다.
# 13. 받은 사랑에 보답하는 일이 어려웠지만, 이제는 더욱 노력하려 합니다.
# 14. 받기만 하는 사랑을 벗어나, 주는 사랑이 되도록 노력하겠습니다.
# 15. 사랑 받는 것에만 치중해왔던 저를 반성하며, 어버이 날을 맞아 더 많이 사랑하는 사람이 되겠습니다.
# 16. 받는 사랑 외에도 주는 사랑이 중요하다는 걸 깨닫게 해줘서 감사합니다.
# 17. 사랑 받는 것에 대해 고맙지만, 이제는 더 많이 주는 사랑을 보여드리겠습니다.
# 18. 받기만 하는 게 아니라 나누는 사랑으로 거듭날 것을 다짐합니다.
# 19. 어버이 날을 맞아 사랑 받는 것 외에도, 사랑을 나누어 주는 마음이 필요하다는 것을 깨닫게 해줘서 고맙습니다.
# 20. 지금까지는 받기만한 사랑에 만족했지만, 이제는 주는 사랑이 되기 위해 노력하겠습니다.
# 21. 당신의 사랑을 받기만 하지 않고 더욱 사랑하는 사람이 될 수 있도록 노력하겠습니다.
# 22. 받기만 하는 사랑이 아니라 당신을 위해 더욱 사랑하는 사람으로 거듭나겠습니다.
# 23. 과분한 사랑을 받았지만, 이제는 그 사랑에 보답하는 주는 사랑으로 변모하겠습니다.
# 24. 사랑 받는 것만큼이나 사랑하는 사람이 되어 드리겠습니다.
# 25. 받는 사랑에 만족하지 않고, 주는 사랑이 되도록 행동하겠습니다.
# 26. 받고만 있던 사랑에 기대하기보다, 주는 사랑으로 거듭나겠습니다.
# 27. 어버이 날을 맞아, 받는 사랑이 아니라 주는 사랑으로 성장하겠습니다.
# 28. 받기만 하지 않고 나누어 주는 사랑의 소중함을 느끼게 해줘서 감사합니다.
# 29. 사랑 받는 것으로 만족하지 않고, 주는 사랑으로 변모하기 위해 노력하겠습니다.
# 30. 어버이 날을 맞아, 받는 사랑이 아니라 나누는 사랑으로 나아가겠습니다.
# 31. 받기만 하는 것이 아닌 그 사랑에 보답하는 주는 사랑이 되도록 하겠습니다.
# 32. 지금까지 받은 사랑에 보답하기보다, 더 많이 주는 사랑으로 모습을 바꾸겠습니다.
# 33. 받은 사랑이 아닌 부탁하고는 다른 주는 사랑으로 변화하겠습니다.
# 34. 사랑 받는 것 외에도 주는 사랑이 중요하다는 것을 깨닫게 해주셔서 감사합니다.
# 35. 어버이 날을 맞아, 받기만 하는 사랑을 벗어나서 나눠주는 사랑으로 성장하겠습니다.
# 36. 사랑 받는 것이 아니라 더욱 사랑하는 사람이 되도록 노력하겠습니다.
# 37. 받기만 했던 사랑에 만족하지 않고, 주는 사랑으로 변화하겠습니다.
# 38. 어버이 날을 맞아, 나누어 주는 사랑이 되기 위해 더 힘쓰겠습니다.
# 39. 받기만 하는 것이 아닌 나누어 주는 사랑으로 성장하기 위해 노력하겠습니다.
# 40. 받은 사랑이 아닌 더 많이 주는 사랑이 되도록 노력하겠습니다.
# 41. 당신의 사랑을 받는 것 외에도 더 많이 주는 사랑을 보여드리겠습니다.
# 42. 받은 사랑에 만족하지 않고, 나누어 주는 사랑으로 성장하겠습니다.
# 43. 어버이 날을 맞아, 받는 사랑이 아니라 주는 사랑으로 변화하겠습니다.
# 44. 사랑 받는 것이 아니라 더욱 사랑하는 마음으로 행동하겠습니다.
# 45. 받기만 하지 않고 주는 사랑으로 거듭나도록 하겠습니다.
# 46. 어버이 날을 맞아, 당신에게 나누어 주는 사랑이 되도록 노력하겠습니다.
# 47. 받는 사랑 말고 주는 사랑에 더 집중하고자 합니다.
# 48. 사랑 받는 것뿐만 아니라 사랑 나누는 마음으로 변모하도록 하겠습니다.
# 49. 받는 사랑에 만족하지 않고, 주는 사랑으로 변화하며 성장하겠습니다.
# 50. 어버이 날을 맞아, 사랑 받는 것이 아니라 나누어 주는 사랑으로 나아가겠습니다.

# %%
save_data_to_csv("etc_2", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 어버이 날을 맞이해서 어버이 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'저를 사랑으로 키워주셔서 감사합니다. 어제보다 오늘 더 사랑해요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "사랑"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 언제나 사랑으로 품어주셔서 감사합니다.
# 2. 사랑으로 이끌어주신 모든 것에 감사드립니다.
# 3. 오늘도 그저 사랑으로 가득해요.
# 4. 사랑으로 저를 이끌어주신 여러분에게 감사드립니다.
# 5. 사랑과 따뜻함으로 가득찬 어버이 날 되세요.
# 6. 어버이님께서 보내주신 그 큰 사랑에 감사드립니다.
# 7. 오늘도 여전히 사랑에 심취합니다.
# 8. 사랑하는 어버이님들께 최고의 하루가 되길 기원합니다.
# 9. 사랑으로 가득한 어버이 날을 보내세요.
# 10. 사랑 받는 그 느낌을 오늘도 느껴보세요.
# 11. 어버이 날을 맞아 사랑의 의미를 다시 한번 생각해보는 좋은 날이죠.
# 12. 사랑은 언제나 빛이 난다는 걸 어버이님께서 더 잘 아시죠.
# 13. 어버이님들께서 보내주신 사랑이 저에게 큰 힘이 되어요.
# 14. 사랑으로 이어지는 이 아름다운 어버이 날을 축하합니다.
# 15. 언제나 사랑 속에서 행복한 시간을 보내기를 바래요.
# 16. 어버이 날을 맞아 사랑과 감사의 마음을 전해봅니다.
# 17. 오늘도 나를 둘러싼 사랑에 감사드립니다.
# 18. 사랑받고 있다는 느낌이 오늘도 따뜻하게 이어져요.
# 19. 어버이 날을 맞이해 사랑의 의미를 더 깊게 생각하게 되네요.
# 20. 오늘의 나는 언제나 사랑에 감싸여 있습니다.
# 21. 사랑하는 어버이님들께 감사와 사랑을 보냅니다.
# 22. 어버이님들의 사랑이 저에게는 무한한 보탬이 되어줘요.
# 23. 오늘도 여전히 사랑으로 가득한 하루가 시작됩니다.
# 24. 사랑으로 이루어지는 따뜻한 어버이 날을 축하합니다.
# 25. 사랑의 힘으로 더 나은 미래를 향해 나아가겠습니다.
# 26. 어버이님들께 받은 사랑이 나의 힘이 됩니다.
# 27. 사랑으로 가득찬 이 특별한 날, 모두 함께 기뻐해요.
# 28. 오늘도 사랑의 빛으로 나의 하루가 빛납니다.
# 29. 언제나 사랑해주시는 어버이님들께 감사를 전합니다.
# 30. 사랑하는 어버이님들께서 오늘도 나를 따뜻하게 감싸주시네요.
# 31. 사랑이 나를 감싸고 있는 이 순간이 너무나 소중합니다.
# 32. 어버이 날을 맞아 사랑과 감사의 마음을 전해드립니다.
# 33. 오늘도 언제나처럼 사랑 빛이 나를 감싸고 있어요.
# 34. 사랑의 연결고리가 되어주시는 어버이님들에게 감사를 드립니다.
# 35. 어버이 날을 맞아 사랑의 의미를 다시 한번 되새겨보는 하루입니다.
# 36. 언제나 사랑의 품 안에서 행복을 느낍니다.
# 37. 어버이님들의 사랑이 빛나는 나의 하루가 시작됩니다.
# 38. 사랑과 이해로 이루어진 특별한 어버이 날을 맞이해요.
# 39. 사랑 받는 마음이 오늘도 가득 차오르네요.
# 40. 어버이님들의 뜨거운 사랑이 나를 더 강하게 만듭니다.
# 41. 사랑으로 이어지는 특별한 어버이 날을 축하합니다.
# 42. 오늘도 나를 둘러싼 사랑에 감사합니다.
# 43. 사랑으로 뒤덮인 어버이 님들의 소중한 기록을 만들어봅니다.
# 44. 어버이님들의 사랑이 지금도 나의 힘이 됩니다.
# 45. 사랑과 감사의 마음을 담아 어버이 날을 맞이해요.
# 46. 사랑이 나를 키워주신 어버이님들에게 감사드립니다.
# 47. 오늘도 사랑의 빛이 나를 따뜻하게 감싸고 있습니다.
# 48. 어버이 날을 맞이해 사랑의 의미를 다시 한번 생각해보세요.
# 49. 사랑과 감사로 이루어진 이 날, 오늘도 행복하게 보내요.
# 50. 언제나 사랑과 이해로 가득한 어버이 날을 맞이합니다.

# %%
save_data_to_csv("250to300", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 스승의 날을 맞이해서 스승의 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'저에게 많은 것을 가르쳐 주시고 바르게 자랄 수 있도록 도와주셔서 감사합니다. 항상 건강하세요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "감사"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 스승님, 저에게 많은 것을 알게 해주시고 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 2. 스승님, 항상 올바른 길로 인도해 주시고 고맙습니다. 건강하시고 행복하세요.
# 3. 스승님, 저의 모든 고민을 들어 주시고 지혜롭게 가르쳐 주셔서 감사합니다. 항상 고맙습니다.
# 4. 스승님, 저에게 지혜로운 조언을 해 주시고 도와 주셔서 감사합니다. 항상 감사드립니다.
# 5. 스승님, 올바른 길로 이끄시고 힘을 실어 주셔서 감사합니다. 항상 고맙습니다.
# 6. 스승님, 항상 저를 응원해 주시고 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 7. 스승님, 끊임없는 가르침과 사랑으로 지켜 주시고 감싸 주셔서 감사합니다. 항상 고맙습니다.
# 8. 스승님, 제게 준 가르침과 따뜻한 사랑에 감사합니다. 항상 건강하시고 행복하세요.
# 9. 스승님, 가르침과 사랑으로 가득해 주신 것에 감사합니다. 항상 고맙습니다.
# 10. 스승님, 항상 저를 밝은 길로 인도해 주시고 감사합니다. 항상 감사드립니다.
# 11. 스승님, 저에게 가르침과 사랑을 베풀어 주셔서 감사합니다. 항상 고맙습니다.
# 12. 스승님, 항상 저를 믿어 주시고 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 13. 스승님, 가르침과 사랑으로 가득한 마음에 감사합니다. 항상 고맙습니다.
# 14. 스승님, 저에게 지혜와 사랑을 선물해 주셔서 감사합니다. 항상 감사드립니다.
# 15. 스승님, 지혜롭게 인도해 주시고 정성껏 가르쳐 주셔서 감사합니다. 항상 고맙습니다.
# 16. 스승님, 항상 빛나는 길을 열어 주시고 감사합니다. 항상 감사드립니다.
# 17. 스승님, 지혜롭게 이끌어 주시고 사랑으로 가득 채워 주셔서 감사합니다. 항상 고맙습니다.
# 18. 스승님, 과분한 사랑과 현명한 가르침에 감사합니다. 항상 감사드립니다.
# 19. 스승님, 정성껏 가르쳐 주시고 지혜롭게 인도해 주셔서 감사합니다. 항상 고맙습니다.
# 20. 스승님, 항상 저를 믿어 주시고 올바른 길로 이끌어 주셔서 감사합니다. 항상 감사드립니다.
# 21. 스승님, 품위와 가르침으로 나의 미래를 밝게 비춰 주셔서 감사합니다. 항상 고맙습니다.
# 22. 스승님, 따뜻한 마음과 지혜를 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 23. 스승님, 항상 저를 향한 관심과 사랑에 감사합니다. 항상 고맙습니다.
# 24. 스승님, 격공한 사랑으로 내 손을 꼭 잡아 주시고 감싸 주셔서 감사합니다. 항상 감사드립니다.
# 25. 스승님, 항상 가르침을 베풀어 주시고 열정으로 지도해 주셔서 감사합니다. 항상 고맙습니다.
# 26. 스승님, 깊은 지혜와 가르침으로 저의 인생을 아름답게 만들어 주셔서 감사합니다. 항상 감사드립니다.
# 27. 스승님, 항상 건강하시고 행복하세요. 정말 감사합니다.
# 28. 스승님, 나를 가르쳐 주시고 선물을 주셔서 감사합니다. 항상 감사드립니다.
# 29. 스승님, 가르침과 사랑으로 가득한 마음에 감사합니다. 항상 고맙습니다.
# 30. 스승님, 항상 올바른 길로 이끌어 주시고 지혜롭게 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 31. 스승님, 저에게 많은 것을 가르쳐 주시고 올바른 길로 이끌어 주셔서 감사합니다. 항상 고맙습니다.
# 32. 스승님, 지혜롭게 가르쳐 주시고 정성껏 도와 주셔서 감사합니다. 항상 감사드립니다.
# 33. 스승님, 항상 저를 뒤에서 응원해 주시고 많은 것을 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 34. 스승님, 고맙습니다. 항상 가르쳐 주시고 사랑으로 지켜 주셔서 감사합니다.
# 35. 스승님, 저를 이끌어 주시고 지혜롭게 가르쳐 주셔서 감사합니다. 항상 고맙습니다.
# 36. 스승님, 항상 저를 믿어 주시고 고마움을 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 37. 스승님, 항상 감사합니다. 저를 인도해 주시고 가르쳐 주셔서 고맙습니다.
# 38. 스승님, 빛나는 가르침으로 제 인생에 밝은 빛을 비춰 주셔서 감사합니다. 항상 고맙습니다.
# 39. 스승님, 항상 저를 이끌어 주시고 정성껏 가르쳐 주셔서 감사합니다. 항상 감사드립니다.
# 40. 스승님, 정말 감사합니다. 깊은 사랑으로 가르침을 베풀어 주셔서 항상 고맙습니다.
# 41. 스승님, 항상 믿음으로 인도해 주시고 품위 있는 가르침에 감사합니다. 항상 감사드립니다.
# 42. 스승님, 인생의 지혜를 가르침으로 나에게 전달해 주시고 감싸 주셔서 감사합니다. 항상 고맙습니다.
# 43. 스승님, 항상 저를 믿어 주셔서 감사합니다. 가르침과 사랑으로 지지해 주셔서 고맙습니다.
# 44. 스승님, 나의 발을 올바른 길로 보내 주실 때마다 감사합니다. 항상 감사드립니다.
# 45. 스승님, 정말 감사합니다. 가르침으로 저의 인생을 채워 주셔서 항상 고맙습니다.
# 46. 스승님, 항상 스승님의 인생 가르침을 통해 저를 이끌어 주셔서 감사합니다. 항상 감사드립니다.
# 47. 스승님, 지혜롭게 가르쳐 주시고 힘을 실어 주셔서 감사합니다. 항상 고맙습니다.
# 48. 스승님, 빛나는 가르침으로 나에게 포근한 따뜻함을 전해 주셔서 감사합니다. 항상 감사드립니다.
# 49. 스승님, 지혜로운 가르침에 항상 감사드립니다. 매 순간, 항상 스승님이 필요합니다.
# 50. 스승님, 항상 저를 사랑으로 뒤에서 지켜 주시고 가르쳐 주셔서 감사합니다. 항상 감사드립니다.

# %%
save_data_to_csv("300to350", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 스승의 날을 맞이해서 스승의 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'저에게 많은 것을 가르쳐 주시고 바르게 자랄 수 있도록 도와주셔서 감사합니다. 항상 건강하세요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "선생님"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 선생님, 저에게는 빠듯하고 가르치고 싶은 것이 많다. 오늘도 감사합니다.
# 2. 선생님, 항상 따뜻한 가르침으로 저를 이끌어 주셔서 감사합니다.
# 3. 선생님, 저의 미래를 밝게 비춰 주시는 선생님 덕분에 변화가 시작되었습니다.
# 4. 선생님, 가르침 속에는 항상 따뜻한 마음이 담겨 있어 감사합니다.
# 5. 선생님, 늘 고맙고 소중한 가르침으로 저를 이끌어 주셔서 감사합니다.
# 6. 선생님, 저의 성장과 발전을 위해 늘 노력해 주셔서 감사합니다.
# 7. 선생님, 항상 따뜻한 눈길로 제 발전을 지켜주시는 모습이 감사합니다.
# 8. 선생님, 감사의 마음을 담아 항상 건강하십시오.
# 9. 선생님, 당신의 가르침은 제 삶에 빛과 희망을 주고 있습니다. 감사합니다.
# 10. 선생님, 저의 꿈을 이룰 수 있도록 끝없이 도와주시는 선생님에게 감사의 인사를 전합니다.
# 11. 선생님, 항상 고맙고 사랑합니다. 당신의 가르침이 저에게는 소중한 자산입니다.
# 12. 선생님, 당신의 가르침은 나무처럼 뿌리 깊게 내려가 에너지와 힘을 주고 있습니다.
# 13. 선생님, 제 마음에 뿌리 깊게 파고들어 끝없이 자랄 수 있도록 도와 주신 것에 감사드립니다.
# 14. 선생님, 항상 저를 믿어주고 끝까지 응원해주셔서 감사합니다.
# 15. 선생님, 온몸으로 가르치시는 모습에 감사하며 항상 건강하시길 바랍니다.
# 16. 선생님, 끝없이 나를 믿어주시고 가르쳐 주심에 감사드립니다.
# 17. 선생님, 항상 저를 먼저 생각해 주시는 따뜻한 마음이 감사합니다.
# 18. 선생님, 늘 저를 위해 필요한 지식과 지혜를 전달해 주셔서 감사합니다.
# 19. 선생님, 항상 옳은 길로 이끌어 주시고 가르쳐 주셔서 감사합니다.
# 20. 선생님, 제 곁에 두고 끝까지 가르치고 도와 주시는 모습에 감사합니다.
# 21. 선생님, 당신의 따뜻한 가르침이 항상 저에게 큰 힘이 됩니다. 감사합니다.
# 22. 선생님, 제 옆에서 늘 응원하고 가르쳐 주시는 것에 감사드립니다.
# 23. 선생님, 당신의 가르침은 제 삶에 큰 빛과 희망을 안겨주고 있습니다. 감사합니다.
# 24. 선생님, 늘 저를 믿어 주시고 가르쳐 주시는 모습에 감사하며 항상 건강하시길 바랍니다.
# 25. 선생님, 저의 성장과 발전을 위해 노력해 주신 것에 감사드립니다. 항상 감사합니다.
# 26. 선생님, 항상 따뜻한 가르침으로 저를 이끌어 주시는 모습이 감사합니다.
# 27. 선생님, 당신은 나의 삶에서 가장 소중한 스승입니다. 항상 감사합니다.
# 28. 선생님, 항상 저를 위해 최선을 다해 가르치고 도와 주시는 모습에 감사드립니다.
# 29. 선생님, 너무나 소중한 가르침을 전해주시고 늘 응원해 주셔서 감사합니다.
# 30. 선생님, 당신의 따뜻한 마음과 가르침이 저에게 큰 힘이 됩니다. 감사합니다.
# 31. 선생님, 항상 저를 믿어주시고 가르치는 모습에 감사합니다. 항상 건강하세요.
# 32. 선생님, 저에게 많은 것을 알려 주시고 도와주어 감사합니다. 항상 건강하세요.
# 33. 선생님, 늘 저를 위해 가르치고 도와주시는 모습에 감사합니다. 항상 감사합니다.
# 34. 선생님, 저를 위해 가르치고 끝까지 도와주시는 모습에 감사합니다. 항상 건강하세요.
# 35. 선생님, 항상 저를 밀어주시고 가르치는 모습에 감사합니다. 항상 건강하세요.
# 36. 선생님, 제게 많은 것을 가르쳐 주시고 도와주셔서 감사합니다. 항상 건강하세요.
# 37. 선생님, 당신의 도움으로 많은 것을 배울 수 있었습니다. 감사합니다. 항상 건강하세요.
# 38. 선생님, 저에게 많은 것을 가르쳐 주시고 도와주어 감사합니다. 항상 건강하시고 행복하세요.
# 39. 선생님, 항상 저에게 따뜻한 가르침과 조언을 해 주시는 모습에 감사합니다. 건강하세요.
# 40. 선생님, 저를 위해 많은 것을 가르쳐 주시고 끝까지 도와주는 모습에 감사합니다. 항상 건강하세요.
# 41. 선생님, 항상 저를 지켜주시고 가르쳐 주시는 모습에 감사합니다. 항상 건강하세요.
# 42. 선생님, 저에게 많은 것을 알려 주시고 도와주어 감사합니다. 항상 건강하시고 행복하세요.
# 43. 선생님, 항상 저를 가르치고 도와주시는 모습에 감사합니다. 항상 건강하세요.
# 44. 선생님, 당신의 끝없는 가르침으로 저는 성장해 나가고 있습니다. 감사합니다. 항상 건강하세요.
# 45. 선생님, 항상 저에게 많은 것을 가르치고 도와주는 모습에 감사합니다. 항상 건강하세요.
# 46. 선생님, 저에게 많은 것을 알려 주시고 끝까지 도와주시는 모습에 감사합니다. 항상 건강하세요.
# 47. 선생님, 항상 저를 이끌어 가며 가르치고 도와주시는 모습에 감사합니다. 항상 건강하세요.
# 48. 선생님, 당신의 따뜻한 사랑과 가르침이 저에게 큰 힘이 됩니다. 감사합니다. 항상 건강하세요.
# 49. 선생님, 항상 저를 믿어주시고 가르치는 모습에 감사합니다. 항상 건강하세요.
# 50. 선생님, 당신의 가르침은 나에게 큰 도움이 되고 있습니다. 감사합니다. 항상 건강하세요.

# %%
save_data_to_csv("350to400", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 스승의 날을 맞이해서 스승의 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'가정의 달 5월에 스승의 날을 맞이하여 감사와 존경의 마음을 전합니다. 늘 건강하시고 행복하세요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "5월"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 5월, 스승의 날을 맞아 감사와 존경을 담아 인사드립니다.
# 2. 5월에 스승의 날을 맞아 건강과 행복이 가득하시길 바랍니다.
# 3. 스승의 달 5월, 항상 고맙고 존경하며 기억하고 있습니다.
# 4. 5월에 스승의 날을 맞이하여 늘 감사와 경의를 표합니다.
# 5. 스승의 날을 맞이하는 5월, 항상 건강하시고 행복하세요.
# 6. 5월은 스승의 달, 항상 감사하고 존경하며 기억합니다.
# 7. 스승의 날을 맞아 5월, 늘 건강하고 행복하시길 바랍니다.
# 8. 5월에 스승의 날을 맞아 존경과 감사의 마음을 전합니다.
# 9. 스승의 날을 맞아 5월, 항상 건강하고 행복하시길 바랍니다.
# 10. 5월은 스승의 날을 맞아 존경과 사랑을 전합니다.
# 11. 스승의 달 5월, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 12. 5월에 스승의 날을 맞아 늘 감사와 존경을 표합니다.
# 13. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 14. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 15. 스승의 날을 맞이하는 5월, 늘 건강하고 행복하시길 바랍니다.
# 16. 5월에 스승의 날을 맞이하여 존경과 감사를 드립니다.
# 17. 스승의 날을 맞아 5월, 항상 건강하고 행복하세요.
# 18. 5월은 스승의 달, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 19. 5월에 스승의 날을 맞아 늘 감사와 존경을 표합니다.
# 20. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 21. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 22. 스승의 날을 맞이하는 5월, 늘 건강하고 행복하시길 바랍니다.
# 23. 5월에 스승의 날을 맞이하여 존경과 감사를 드립니다.
# 24. 스승의 날을 맞아 5월, 항상 건강하고 행복하세요.
# 25. 5월은 스승의 달, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 26. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 27. 5월에 스승의 날을 맞아 늘 감사와 존경을 표합니다.
# 28. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 29. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 30. 5월에 스승의 날을 맞이하여 존경과 감사를 드립니다.
# 31. 스승의 날을 맞아 5월, 항상 건강하고 행복하세요.
# 32. 5월은 스승의 달, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 33. 5월에 스승의 날을 맞이하여 늘 감사와 존경을 표합니다.
# 34. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 35. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 36. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 37. 5월에 스승의 날을 맞아 존경과 감사를 드립니다.
# 38. 스승의 날을 맞아 5월, 항상 건강하고 행복하세요.
# 39. 5월은 스승의 달, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 40. 5월에 스승의 날을 맞이하여 늘 감사와 존경을 표합니다.
# 41. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 42. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 43. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 44. 5월에 스승의 날을 맞아 존경과 감사를 드립니다.
# 45. 스승의 날을 맞아 5월, 항상 건강하고 행복하세요.
# 46. 5월은 스승의 달, 항상 감사하고 존경하며 빛나는 마음으로 생각합니다.
# 47. 5월에 스승의 날을 맞이하여 늘 감사와 존경을 표합니다.
# 48. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.
# 49. 5월은 스승의 달, 항상 감사하고 존경한 마음을 전합니다.
# 50. 스승의 날을 맞이하는 5월, 늘 건강하시고 행복하세요.

# %%
save_data_to_csv("400to450", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 스승의 날을 맞이해서 스승의 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'그동안 잘 지내셨어요? 언제나 좋은 말씀 많이 해 주시고 도움 주셔서 감사해요. 앞으로도 건강하시고 행복하시길 바랄게요. 그리고 곧 찾아뵐게요. 안녕히 계세요.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "선생님 & 사랑"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 선생님, 그동안 수고 많으셨어요. 사랑합니다.
# 2. 선생님, 항상 저를 믿어주시고 사랑해주셔서 감사해요.
# 3. 선생님, 제게 가르쳐주신 모든 것에 사랑을 담아 감사드려요.
# 4. 선생님, 항상 따뜻한 사랑으로 저를 이끌어주셔서 감사합니다.
# 5. 선생님, 앞으로도 저에게 많은 사랑과 지혜를 전해주시길 바랄게요.
# 6. 선생님, 제게 가르쳐주신 모든 것을 사랑하고 감사하고 있어요.
# 7. 선생님, 당신께 받은 사랑은 저에게 큰 힘이 되어요.
# 8. 선생님의 사랑이 저에게는 얼마나 소중한지 잘 알고 있어요.
# 9. 선생님, 항상 사랑으로 가득한 모습으로 제 곁에 계셔주세요.
# 10. 선생님, 저의 성장을 위해 주신 모든 사랑에 감사드려요.

# %%
save_data_to_csv("etc_3", response_text)

# %%
response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      messages=[
        {
          "role": "system",
          "content": "너는 스승의 날을 맞이해서 스승의 날 안부 인사말을 생성해내는 한국어 인사말 문장 생성기야."
        },
        {
          "role": "user",
          "content": "'스승의 날을 맞아 평소 존경하던 교수님께 감사 인사드립니다. 부족한 저를 바른길로 인도해 주셔서 감사합니다. 앞으로도 잘 부탁드립니다.' 와 같은 문장 생성해줘"
        },
        {
          "role": "assistant",
          "content": "어떤 키워드를 넣어드릴까요?"
        },
        {
          "role": "user",
          "content": "교수님"
        },
        {
          "role": "assistant",
          "content": "몇개의 문장을 생성해드릴까요?"
        },
        {
          "role": "user",
          "content": "50개 생성해줘"
        },
        ])

response_text = response.choices[0].message.content

print(response_text)
# Out:
# 1. 스승의 날을 맞이해 귀한 교수님께 감사의 마음을 전합니다. 지혜와 가르침으로 저를 이끌어주셔서 감사합니다.
# 2. 존경하는 교수님께 스승의 날을 맞아 감사의 인사를 드립니다. 항상 진정한 멘토로써 감사합니다.
# 3. 스승의 날을 맞아 존경하는 교수님께 감사 인사를 전합니다. 항상 올바른 길로 이끌어주셔서 감사합니다.
# 4. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 지식과 지혜를 전해주셔서 감사합니다.
# 5. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 드립니다. 선생님의 가르침으로 빛이 나게 해주셔서 감사합니다.
# 6. 교수님께 스승의 날을 맞아 감사의 말씀을 전합니다. 지혜로운 가르침에 무한한 존경과 감사를 표합니다.
# 7. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 지식과 지혜로 저를 이끌어 주신 것에 감사합니다.
# 8. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 끊임없는 가르침으로 저를 발전시켜 주셔서 감사합니다.
# 9. 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 진정한 멘토로써의 가르침에 감사하며 존경합니다.
# 10. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 지혜롭고 숭고한 가르침에 감사를 표합니다.
# 11. 귀한 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 지식과 인도에 감사드립니다.
# 12. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 드립니다. 항상 가르치고 인도해 주셔서 감사합니다.
# 13. 교수님께 스승의 날을 맞아 감사의 말을 전합니다. 지혜롭고 가르치신 가르침에 감사를 드립니다.
# 14. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 지식과 지혜로 이끌어주신 것에 감사를 표합니다.
# 15. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 차분하고 지혜로운 가르침에 감사합니다.
# 16. 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 지혜롭게 이끄시면서 고마움을 느낍니다.
# 17. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 선생님의 가르침에 감사를 드립니다.
# 18. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 항상 곁에서 가르쳐 주시는 고마움을 전합니다.
# 19. 스승의 날을 맞아 존경하는 교수님께 감사 인사를 드립니다. 지혜롭게 가르쳐 주신 것에 감사합니다.
# 20. 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 사랑과 이해로 가르쳐 주시는 고마움을 표합니다.
# 21. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 항상 올바르게 이끄시는 가르침에 감사합니다.
# 22. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 진정한 지도자로써 감사를 표합니다.
# 23. 교수님께 스승의 날을 맞아 감사의 말을 전합니다. 앞날을 밝게 이끌어 주시는 고마움을 느낍니다.
# 24. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 지혜롭고 고귀한 가르침에 감사를 드립니다.
# 25. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 지식과 인도에 무한한 고마움을 전합니다.
# 26. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 드립니다. 정직하고 인도하여 주신 것에 감사합니다.
# 27. 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 깊은 사랑으로 이끌어 주신 고마움을 표합니다.
# 28. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 지혜롭게 이끌어 주시는 가르침에 감사를 표합니다.
# 29. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 참된 멘토로써의 고마움을 느낍니다.
# 30. 교수님께 스승의 날을 맞아 감사의 말을 전합니다. 지혜롭게 가르침으로 인도하여 주신 것에 감사를 드립니다.
# 31. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 선생님의 가르침에 감사를 드리며 존경합니다.
# 32. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 항상 올바른 길로 인도하여 주시는 고마움을 표합니다.
# 33. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 드립니다. 지혜롭게 가르쳐 주시는 것에 고마워 합니다.
# 34. 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 지혜와 이해를 전하시는 고마움을 표합니다.
# 35. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 성실하고 공정한 가르침에 감사를 표합니다.
# 36. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 헌신적인 가르침으로 감사를 표합니다.
# 37. 교수님께 스승의 날을 맞아 감사의 말을 전합니다. 노고를 아끼지 않고 가르쳐 주시는 고마움을 느낍니다.
# 38. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 지혜롭게 이끄시는 가르침에 감사를 드립니다.
# 39. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 지식과 헌신에 감사를 드립니다.
# 40. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 선생님의 가르침으로 저를 이끌어 주셔서 감사합니다.
# 41. 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 정성과 사랑을 담아 가르쳐 주신 고마움을 표합니다.
# 42. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 참된 선생님의 지도에 감사를 표합니다.
# 43. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 지혜롭게 이끄시는 가르침에 감사를 표합니다.
# 44. 교수님께 스승의 날을 맞아 감사의 말을 전합니다. 지식과 지혜를 전하시는 고마움을 느끼며 감사를 표합니다.
# 45. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 드립니다. 정직하고 성실한 가르침에 감사를 드립니다.
# 46. 귀한 교수님께 스승의 날을 맞아 감사의 인사말을 전합니다. 지혜롭게 가르쳐 주신 것에 감사를 표합니다.
# 47. 스승의 날을 맞아 존경하는 교수님에게 감사 인사를 전합니다. 지혜롭게 가르침으로 인도하여 주신 것에 감사를 드립니다.
# 48. 교수님께 스승의 날을 맞아 감사의 인사를 전합니다. 진실하게 사랑과 이해로 가르쳐 주신 것에 감사를 드립니다.
# 49. 스승의 날을 맞아 귀한 교수님께 감사 인사를 전합니다. 성실하고 공정한 가르침에 감사를 표합니다.
# 50. 존경하는 교수님께 스승의 날을 맞아 감사 인사를 전합니다. 지혜롭게 이끄시는 가르침에 감사를 표합니다.

# %%
save_data_to_csv("450to500", response_text)

# %% [markdown]
# ##Concatenation

# %%
ls
# Out:
# 0to50.csv            250to300.csv         etc_2.csv
# 100to150.csv         50to100.csv          raw/
# 150to200.csv         data_creation.ipynb
# 200to250.csv         etc_1.csv

# %%
data_1 = pd.read_csv('0to50.csv')
data_2 = pd.read_csv('50to100.csv')
data_3 = pd.read_csv('100to150.csv')
data_4 = pd.read_csv('150to200.csv')
data_5 = pd.read_csv('200to250.csv')
data_6 = pd.read_csv('250to300.csv')
# data_7 = pd.read_csv('300to350.csv')
# data_8 = pd.read_csv('350to400.csv')
# data_9 = pd.read_csv('400to450.csv')
# data_10 = pd.read_csv('450to500.csv')
data_11 = pd.read_csv('etc_1.csv')
data_12 = pd.read_csv('etc_2.csv')
# data_13 = pd.read_csv('etc_3.csv')

# %%
data_13
# Out:
#    id                              sentence  label
# 0   1             선생님, 그동안 수고 많으셨어요. 사랑합니다.     10
# 1   2         선생님, 항상 저를 믿어주시고 사랑해주셔서 감사해요.     10
# 2   3     선생님, 제게 가르쳐주신 모든 것에 사랑을 담아 감사드려요.     10
# 3   4     선생님, 항상 따뜻한 사랑으로 저를 이끌어주셔서 감사합니다.     10
# 4   5  선생님, 앞으로도 저에게 많은 사랑과 지혜를 전해주시길 바랄게요.     10
# 5   6    선생님, 제게 가르쳐주신 모든 것을 사랑하고 감사하고 있어요.     10
# 6   7         선생님, 당신께 받은 사랑은 저에게 큰 힘이 되어요.     10
# 7   8      선생님의 사랑이 저에게는 얼마나 소중한지 잘 알고 있어요.     10
# 8   9     선생님, 항상 사랑으로 가득한 모습으로 제 곁에 계셔주세요.     10
# 9  10       선생님, 저의 성장을 위해 주신 모든 사랑에 감사드려요.     10

# %%
concatenated_df = pd.concat([data_1, data_2, data_3,data_4, data_5, data_6, data_11, data_12], ignore_index=True)

# Display the concatenated DataFrame
print(concatenated_df)
# Out:
#      id                                      sentence  label
# 0     1                   부모님께서 항상 효도로 가르침 주셔서 감사합니다.     10
# 1     2               언제나 저희를 위해 헌신해주시는 부모님에게 감사드립니다.     10
# 2     3                  부모님의 효도 정신에 감동받아 더욱 노력하겠습니다.     10
# 3     4              늘 효도의 중요성을 깨닫게 해주시는 부모님께 감사드립니다.     10
# 4     5                 부모님의 사랑과 효도 정신이 저에게 큰 힘이 됩니다.     10
# ..   ..                                           ...    ...
# 330  46       어버이 날을 맞아, 당신에게 나누어 주는 사랑이 되도록 노력하겠습니다.     10
# 331  47                  받는 사랑 말고 주는 사랑에 더 집중하고자 합니다.     10
# 332  48        사랑 받는 것뿐만 아니라 사랑 나누는 마음으로 변모하도록 하겠습니다.     10
# 333  49         받는 사랑에 만족하지 않고, 주는 사랑으로 변화하며 성장하겠습니다.     10
# 334  50  어버이 날을 맞아, 사랑 받는 것이 아니라 나누어 주는 사랑으로 나아가겠습니다.     10
#
# [335 rows x 3 columns]

# %%
concatenated_df.to_csv("parents_day.csv", index=False, encoding='utf-8-sig')

# %%
final_data = pd.read_csv('parents_day.csv')
final_data.to_csv('parents_day.txt', sep='\t', index=False)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/h/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/h/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/h/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/h/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train, test = train_test_split(final_data, test_size=0.15, random_state=42)

# Save the training and testing sets to CSV files
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)

# Save the training and testing sets to TEXT files
train.to_csv('train.txt', sep='\t', index=False)
test.to_csv('test.txt', sep='\t', index=False)
