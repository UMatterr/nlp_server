# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/haeun_classification/data
# Out:
# /gdrive/MyDrive/haeun_classification/data

# %%
ls
# Out:
# cached_test_BertTokenizer_128_data_document-classification        test.txt
# cached_test_BertTokenizer_128_data_document-classification.lock   train.csv
# cached_train_BertTokenizer_128_data_document-classification       train.txt
# cached_train_BertTokenizer_128_data_document-classification.lock  Untitled0.ipynb
# test.csv

# %%
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#             id                                          sentences  cleaned
# 0            1                                아 더빙.. 진짜 짜증나네요 목소리        0
# 1            2                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나        0
# 2            3                                  너무재밓었다그래서보는것을추천한다        1
# 3            4                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정        0
# 4            5  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...        1
# ...        ...                                                ...      ...
# 167930  167931                       희망의 기운으로 가득찬 2019가 되시길 바랍니다.        1
# 167931  167932                   지난해는 물론이고 앞으로도 좋은 일들이 계속되길 바랍니다.        1
# 167932  167933  올해는 더 나은 내일을 향한 출발이 되기를 기대하며 행복과 건강이 가득한 해가 되길...        1
# 167933  167934                           좋은 일만 가득한 한 해가 되길 기대합니다.        1
# 167934  167935                           좋은 일만 가득한 한 해가 되길 기원합니다.        1
#
# [167935 rows x 3 columns]

# %%
test
# Out:
#           id                                          sentences  clean
# 0          1                                                굳 ㅋ      1
# 1          2                               GDNTOPCLASSINTHECLUB      0
# 2          3             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3          4                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4          5  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...      ...                                                ...    ...
# 53759  53760               모든 이가 행복한 기운에 감싸여 행복이 가득한 해가 되길 바라요.      1
# 53760  53761                             올해는 더 많은 성취와 행운이 함께하길.      1
# 53761  53762                             건강하고 행복한 한 해 되시길 바랍니다.      1
# 53762  53763                            새해가 시작되었습니다. 행복을 찾아주세요.      1
# 53763  53764                         새해의 모든 소망을 모두 이루는 날들이 되세요.      1
#
# [53764 rows x 3 columns]

# %%
train.to_csv("train.txt", sep = '\t', index = False)
test.to_csv('test.txt', sep='\t', index=False)
